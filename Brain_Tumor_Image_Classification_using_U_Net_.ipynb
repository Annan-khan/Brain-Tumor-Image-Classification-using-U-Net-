# %% [markdown]
# <a href="https://colab.research.google.com/github/Annan-khan/Brain-Tumor-Image-Classification-using-U-Net-/blob/main/Brain_Tumor_Image_Classification_using_U_Net_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Conv2DTranspose, concatenate, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
import kagglehub
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from google.colab import files
from PIL import Image
import io
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Download the dataset using kagglehub
path = kagglehub.dataset_download("aryashah2k/breast-ultrasound-images-dataset")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/breast-ultrasound-images-dataset

# %%
# Function to create model architecture
def conv_block(input_tensor, num_filters):
    x = Conv2D(num_filters, 3, activation='relu', padding='same')(input_tensor)
    x = Dropout(0.1)(x)
    x = Conv2D(num_filters, 3, activation='relu', padding='same')(x)
    return x

def encoder_block(input_tensor, num_filters):
    x = conv_block(input_tensor, num_filters)
    p = MaxPooling2D((2, 2))(x)
    return x, p

def decoder_block(input_tensor, skip_tensor, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
    x = concatenate([x, skip_tensor])
    x = conv_block(x, num_filters)
    return x

def build_multitask_unet(input_shape=(128, 128, 3), num_classes=3):
    inputs = Input(input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    # Bottleneck
    b = conv_block(p4, 1024)

    # Decoder (Segmentation branch)
    d1 = decoder_block(b, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    seg_output = Conv2D(1, (1, 1), activation='sigmoid', name='segmentation')(d4)

    # Classification branch from bottleneck
    cls_branch = GlobalAveragePooling2D()(b)
    cls_branch = Dense(128, activation='relu')(cls_branch)
    cls_branch = Dropout(0.3)(cls_branch)
    cls_output = Dense(num_classes, activation='softmax', name='classification')(cls_branch)

    model = Model(inputs, outputs=[seg_output, cls_output])
    return model

# %%
# Function to load and preprocess data
def load_data(path, img_size=(128, 128)):
    # Define category folders and their classes
    categories = {
        'normal': 0,
        'benign': 1,
        'malignant': 2
    }

    images = []
    masks = []
    labels = []


    dataset_path = os.path.join(path, "Dataset_BUSI_with_GT")

    for category in categories.keys():
        category_path = os.path.join(dataset_path, category)

        # Get all images in this category (they end with .png and don't have "_mask" in the name)
        img_paths = [f for f in glob(os.path.join(category_path, "*.png")) if "_mask" not in f]

        for img_path in img_paths:
            # Load image
            img = cv2.imread(img_path)
            if img is None:
                print(f"Failed to load image: {img_path}")
                continue

            # Corresponding mask (same name but with _mask)
            mask_path = img_path.replace(".png", "_mask.png")
            if os.path.exists(mask_path):
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            else:
                # If no mask exists (normal cases might not have masks), create empty mask
                mask = np.zeros((img.shape[0], img.shape[1]), dtype=np.uint8)

            # Resize
            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            # Normalize image to [0,1]
            img = img / 255.0

            # Binarize mask (threshold at 128)
            mask = (mask > 128).astype(np.float32)
            mask = np.expand_dims(mask, axis=-1)  # Add channel dimension

            # Append to collections
            images.append(img)
            masks.append(mask)
            labels.append(categories[category])

    # Convert to numpy arrays
    X = np.array(images)
    y_seg = np.array(masks)
    y_cls = to_categorical(np.array(labels), num_classes=len(categories))

    return X, y_seg, y_cls

# %%
# Load the data
print("Loading and preprocessing data...")
X, y_seg, y_cls = load_data(path)
print(f"Loaded {len(X)} images")
print(f"Class distribution: {np.sum(y_cls, axis=0)}")
# Out:
# Loading and preprocessing data...
# Loaded 780 images
# Class distribution: [133. 437. 210.]

# %%
# Split the data
X_train, X_val, y_train_seg, y_val_seg, y_train_cls, y_val_cls = train_test_split(
    X, y_seg, y_cls, test_size=0.2, random_state=42, stratify=np.argmax(y_cls, axis=1)
)

print(f"Training set: {X_train.shape[0]} samples")
print(f"Validation set: {X_val.shape[0]} samples")
# Out:
# Training set: 624 samples
# Validation set: 156 samples

# %%
# Build and compile the model
model = build_multitask_unet(input_shape=X_train.shape[1:])
model.summary()

alpha = 0.8 # Weight for segmentation loss
beta = 0.2 # Weight for classification loss

# Compile the model with weighted loss
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss={
        'segmentation': lambda y_true, y_pred: alpha * tf.keras.losses.binary_crossentropy(y_true, y_pred),
        'classification': lambda y_true, y_pred: beta * tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    },
    metrics={
        'segmentation': [MeanIoU(num_classes=2), 'accuracy'],
        'classification': ['accuracy']
    }
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    147,584 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    590,080 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8,      │          0 │ conv2d_8[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8,      │  9,438,208 │ dropout_4[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │  2,097,664 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_10[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ dropout_5[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │    524,544 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ dropout_6[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │    131,200 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ dropout_7[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │     32,832 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ conv2d_9[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_16[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    131,200 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ dropout_8[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation        │ (None, 128, 128,  │         65 │ conv2d_17[0][0]   │
# │ (Conv2D)            │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification      │ (None, 3)         │        387 │ dropout_9[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,163,332 (118.88 MB)
#  Trainable params: 31,163,332 (118.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Callbacks
callbacks = [
    ModelCheckpoint('breast_ultrasound_model.h5', save_best_only=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-6),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
]

# %%
# Train the model
history = model.fit(
    X_train,
    {'segmentation': y_train_seg, 'classification': y_train_cls},
    validation_data=(X_val, {'segmentation': y_val_seg, 'classification': y_val_cls}),
    epochs=100,
    batch_size=16,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - classification_accuracy: 0.5824 - classification_loss: 0.2055 - loss: 0.6593 - segmentation_accuracy: 0.8618 - segmentation_loss: 0.4538 - segmentation_mean_io_u: 0.4616
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 76s 853ms/step - classification_accuracy: 0.5819 - classification_loss: 0.2055 - loss: 0.6570 - segmentation_accuracy: 0.8630 - segmentation_loss: 0.4515 - segmentation_mean_io_u: 0.4616 - val_classification_accuracy: 0.5577 - val_classification_loss: 0.1987 - val_loss: 0.4478 - val_segmentation_accuracy: 0.9204 - val_segmentation_loss: 0.2490 - val_segmentation_mean_io_u: 0.4602 - learning_rate: 1.0000e-04
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - classification_accuracy: 0.5756 - classification_loss: 0.1945 - loss: 0.4479 - segmentation_accuracy: 0.9233 - segmentation_loss: 0.2534 - segmentation_mean_io_u: 0.4616
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 25s 284ms/step - classification_accuracy: 0.5752 - classification_loss: 0.1946 - loss: 0.4477 - segmentation_accuracy: 0.9233 - segmentation_loss: 0.2531 - segmentation_mean_io_u: 0.4616 - val_classification_accuracy: 0.5577 - val_classification_loss: 0.2005 - val_loss: 0.4219 - val_segmentation_accuracy: 0.9204 - val_segmentation_loss: 0.2213 - val_segmentation_mean_io_u: 0.4602 - learning_rate: 1.0000e-04
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - classification_accuracy: 0.5756 - classification_loss: 0.1938 - loss: 0.3946 - segmentation_accuracy: 0.9233 - segmentation_loss: 0.2008 - segmentation_mean_io_u: 0.4616
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━
100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - classification_accuracy: 0.8788 - classification_loss: 0.0644 - loss: 0.1434 - segmentation_accuracy: 0.9619 - segmentation_loss: 0.0791 - segmentation_mean_io_u: 0.4622 - val_classification_accuracy: 0.7115 - val_classification_loss: 0.1293 - val_loss: 0.2245 - val_segmentation_accuracy: 0.9572 - val_segmentation_loss: 0.0934 - val_segmentation_mean_io_u: 0.4647 - learning_rate: 1.0000e-04
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 11s 280ms/step - classification_accuracy: 0.8886 - classification_loss: 0.0616 - loss: 0.1324 - segmentation_accuracy: 0.9654 - segmentation_loss: 0.0708 - segmentation_mean_io_u: 0.4645 - val_classification_accuracy: 0.7564 - val_classification_loss: 0.1218 - val_loss: 0.2186 - val_segmentation_accuracy: 0.9564 - val_segmentation_loss: 0.0949 - val_segmentation_mean_io_u: 0.4617 - learning_rate: 1.0000e-04
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - classification_accuracy: 0.8861 - classification_loss: 0.0598 - loss: 0.1313 - segmentation_accuracy: 0.9649 - segmentation_loss: 0.0714 - segmentation_mean_io_u: 0.4644
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 27s 441ms/step - classification_accuracy: 0.8865 - classification_loss: 0.0596 - loss: 0.1309 - segmentation_accuracy: 0.9650 - segmentation_loss: 0.0713 - segmentation_mean_io_u: 0.4644 - val_classification_accuracy: 0.7949 - val_classification_loss: 0.1166 - val_loss: 0.2034 - val_segmentation_accuracy: 0.9594 - val_segmentation_loss: 0.0850 - val_segmentation_mean_io_u: 0.4611 - learning_rate: 1.0000e-05
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 14s 276ms/step - classification_accuracy: 0.9257 - classification_loss: 0.0435 - loss: 0.1034 - segmentation_accuracy: 0.9695 - segmentation_loss: 0.0599 - segmentation_mean_io_u: 0.4630 - val_classification_accuracy: 0.8141 - val_classification_loss: 0.1196 - val_loss: 0.2073 - val_segmentation_accuracy: 0.9600 - val_segmentation_loss: 0.0857 - val_segmentation_mean_io_u: 0.4615 - learning_rate: 1.0000e-05
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 268ms/step - classification_accuracy: 0.9248 - classification_loss: 0.0416 - loss: 0.0995 - segmentation_accuracy: 0.9707 - segmentation_loss: 0.0579 - segmentation_mean_io_u: 0.4630 - val_classification_accuracy: 0.7885 - val_classification_loss: 0.1243 - val_loss: 0.2127 - val_segmentation_accuracy: 0.9600 - val_segmentation_loss: 0.0862 - val_segmentation_mean_io_u: 0.4616 - learning_rate: 1.0000e-05
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 279ms/step - classification_accuracy: 0.9249 - classification_loss: 0.0426 - loss: 0.0988 - segmentation_accuracy: 0.9713 - segmentation_loss: 0.0562 - segmentation_mean_io_u: 0.4639 - val_classification_accuracy: 0.7949 - val_classification_loss: 0.1262 - val_loss: 0.2152 - val_segmentation_accuracy: 0.9600 - val_segmentation_loss: 0.0867 - val_segmentation_mean_io_u: 0.4613 - learning_rate: 1.0000e-05
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 276ms/step - classification_accuracy: 0.9475 - classification_loss: 0.0321 - loss: 0.0871 - segmentation_accuracy: 0.9718 - segmentation_loss: 0.0549 - segmentation_mean_io_u: 0.4642 - val_classification_accuracy: 0.7949 - val_classification_loss: 0.1307 - val_loss: 0.2205 - val_segmentation_accuracy: 0.9601 - val_segmentation_loss: 0.0873 - val_segmentation_mean_io_u: 0.4621 - learning_rate: 1.0000e-05
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 278ms/step - classification_accuracy: 0.9454 - classification_loss: 0.0325 - loss: 0.0859 - segmentation_accuracy: 0.9727 - segmentation_loss: 0.0534 - segmentation_mean_io_u: 0.4654 - val_classification_accuracy: 0.8141 - val_classification_loss: 0.1306 - val_loss: 0.2212 - val_segmentation_accuracy: 0.9605 - val_segmentation_loss: 0.0880 - val_segmentation_mean_io_u: 0.4621 - learning_rate: 1.0000e-05
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 278ms/step - classification_accuracy: 0.9585 - classification_loss: 0.0287 - loss: 0.0803 - segmentation_accuracy: 0.9738 - segmentation_loss: 0.0516 - segmentation_mean_io_u: 0.4659 - val_classification_accuracy: 0.8141 - val_classification_loss: 0.1304 - val_loss: 0.2213 - val_segmentation_accuracy: 0.9606 - val_segmentation_loss: 0.0883 - val_segmentation_mean_io_u: 0.4617 - learning_rate: 1.0000e-06
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - classification_accuracy: 0.9497 - classification_loss: 0.0275 - loss: 0.0792 - segmentation_accuracy: 0.9736 - segmentation_loss: 0.0516 - segmentation_mean_io_u: 0.4658 - val_classification_accuracy: 0.8141 - val_classification_loss: 0.1307 - val_loss: 0.2218 - val_segmentation_accuracy: 0.9606 - val_segmentation_loss: 0.0885 - val_segmentation_mean_io_u: 0.4618 - learning_rate: 1.0000e-06
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 277ms/step - classification_accuracy: 0.9589 - classification_loss: 0.0284 - loss: 0.0795 - segmentation_accuracy: 0.9740 - segmentation_loss: 0.0511 - segmentation_mean_io_u: 0.4659 - val_classification_accuracy: 0.8077 - val_classification_loss: 0.1311 - val_loss: 0.2225 - val_segmentation_accuracy: 0.9606 - val_segmentation_loss: 0.0887 - val_segmentation_mean_io_u: 0.4618 - learning_rate: 1.0000e-06
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 278ms/step - classification_accuracy: 0.9618 - classification_loss: 0.0274 - loss: 0.0788 - segmentation_accuracy: 0.9736 - segmentation_loss: 0.0514 - segmentation_mean_io_u: 0.4661 - val_classification_accuracy: 0.8077 - val_classification_loss: 0.1321 - val_loss: 0.2236 - val_segmentation_accuracy: 0.9606 - val_segmentation_loss: 0.0888 - val_segmentation_mean_io_u: 0.4618 - learning_rate: 1.0000e-06
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 278ms/step - classification_accuracy: 0.9571 - classification_loss: 0.0276 - loss: 0.0785 - segmentation_accuracy: 0.9739 - segmentation_loss: 0.0509 - segmentation_mean_io_u: 0.4654 - val_classification_accuracy: 0.8077 - val_classification_loss: 0.1326 - val_loss: 0.2243 - val_segmentation_accuracy: 0.9605 - val_segmentation_loss: 0.0889 - val_segmentation_mean_io_u: 0.4619 - learning_rate: 1.0000e-06

# %%
# Plot training history
def plot_history(history):
    plt.figure(figsize=(15, 5))

    # Plot loss
    plt.subplot(1, 3, 1)
    plt.plot(history.history['segmentation_loss'], label='Segmentation Loss')
    plt.plot(history.history['classification_loss'], label='Classification Loss')
    plt.plot(history.history['val_segmentation_loss'], label='Val Segmentation Loss')
    plt.plot(history.history['val_classification_loss'], label='Val Classification Loss')
    plt.title('Loss')
    plt.legend()

    # Plot segmentation accuracy
    plt.subplot(1, 3, 2)
    plt.plot(history.history['segmentation_accuracy'], label='Segmentation Accuracy')
    plt.plot(history.history['val_segmentation_accuracy'], label='Val Segmentation Accuracy')
    plt.title('Segmentation Accuracy')
    plt.legend()

    # Plot classification accuracy
    plt.subplot(1, 3, 3)
    plt.plot(history.history['classification_accuracy'], label='Classification Accuracy')
    plt.plot(history.history['val_classification_accuracy'], label='Val Classification Accuracy')
    plt.title('Classification Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

plot_history(history)

# %%
# Function to visualize predictions
def visualize_predictions(model, X, y_seg, y_cls, num_samples=5):
    # Get predictions
    seg_pred, cls_pred = model.predict(X)

    # Class names
    class_names = ['Normal', 'Benign', 'Malignant']

    plt.figure(figsize=(20, 4*num_samples))

    for i in range(num_samples):
        # Original image
        plt.subplot(num_samples, 4, i*4+1)
        plt.imshow(X[i])
        plt.title(f'Image: {class_names[np.argmax(y_cls[i])]}')
        plt.axis('off')

        # Ground truth mask
        plt.subplot(num_samples, 4, i*4+2)
        plt.imshow(y_seg[i, :, :, 0], cmap='gray')
        plt.title('Ground Truth Mask')
        plt.axis('off')

        # Predicted mask
        plt.subplot(num_samples, 4, i*4+3)
        plt.imshow(seg_pred[i, :, :, 0], cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

        # Comparison
        plt.subplot(num_samples, 4, i*4+4)
        plt.imshow(X[i])
        plt.imshow(seg_pred[i, :, :, 0], alpha=0.5, cmap='jet')
        pred_class = np.argmax(cls_pred[i])
        true_class = np.argmax(y_cls[i])
        plt.title(f'Pred: {class_names[pred_class]}\nTrue: {class_names[true_class]}')
        plt.axis('off')

    plt.tight_layout()
    plt.savefig('predictions.png')
    plt.show()

print("Generating visualizations...")
visualize_predictions(model, X_val, y_val_seg, y_val_cls)
# Out:
# Generating visualizations...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 4s/step

# %%
# Predict on validation data
y_pred_seg, y_pred_cls = model.predict(X_val)

# Threshold segmentation predictions
y_pred_seg_bin = (y_pred_seg > 0.5).astype(np.uint8)
y_true_seg_bin = (y_val_seg > 0.5).astype(np.uint8)

# SEGMENTATION METRICS

# 1. Mean IoU
miou = MeanIoU(num_classes=2)
miou.update_state(y_true_seg_bin, y_pred_seg_bin)
mean_iou = miou.result().numpy()

# 2. Dice Coefficient
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

dice = dice_coef(y_true_seg_bin, y_pred_seg_bin)

# 3. Pixel Accuracy
pixel_acc = np.mean(y_true_seg_bin == y_pred_seg_bin)


# CLASSIFICATION METRICS

y_true_cls = np.argmax(y_val_cls, axis=1)
y_pred_cls_labels = np.argmax(y_pred_cls, axis=1)

cls_acc = accuracy_score(y_true_cls, y_pred_cls_labels)
cls_precision = precision_score(y_true_cls, y_pred_cls_labels, average='macro', zero_division=0)
cls_recall = recall_score(y_true_cls, y_pred_cls_labels, average='macro', zero_division=0)
cls_f1 = f1_score(y_true_cls, y_pred_cls_labels, average='macro', zero_division=0)

# PRINT RESULTS
print("\n--- SEGMENTATION METRICS ---")
print(f"Mean IoU:        {mean_iou:.4f}")
print(f"Dice Coefficient:{dice:.4f}")
print(f"Pixel Accuracy:  {pixel_acc:.4f}")

print("\n--- CLASSIFICATION METRICS ---")
print(f"Accuracy:        {cls_acc:.4f}")
print(f"Precision:       {cls_precision:.4f}")
print(f"Recall:          {cls_recall:.4f}")
print(f"F1-Score:        {cls_f1:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
#
# --- SEGMENTATION METRICS ---
# Mean IoU:        0.7593
# Dice Coefficient:0.7191
# Pixel Accuracy:  0.9594
#
# --- CLASSIFICATION METRICS ---
# Accuracy:        0.7949
# Precision:       0.7948
# Recall:          0.7603
# F1-Score:        0.7741

# %%
# CONFUSION MATRIX

# Compute confusion matrix
cm = confusion_matrix(y_true_cls, y_pred_cls_labels)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Benign', 'Malignant'])

plt.figure(figsize=(6, 6))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix - Classification")
plt.grid(False)
plt.savefig('confusion_matrix.png')
plt.show()

# %%
model.save('breast_ultrasound_multitask_model.h5')
print("Model saved successfully!")

# %%
# Helper: Preprocess uploaded image
def preprocess_image(image, target_size=(128, 128)):
    image = image.convert('RGB')
    image = image.resize(target_size)
    img_array = img_to_array(image) / 255.0
    return np.expand_dims(img_array, axis=0)

# Helper: Overlay mask on image
def overlay_mask(image, mask, alpha=0.5):
    image = np.array(image.resize(mask.shape[::-1])) / 255.0
    overlay = image.copy()
    overlay[mask > 0.5] = [1, 0, 0]
    return (alpha * image + (1 - alpha) * overlay)

# Upload and predict
from tensorflow.keras.models import load_model
model = load_model('path_to_your_model.h5')
uploaded = files.upload()
for filename in uploaded.keys():
    # Load and preprocess
    img_pil = Image.open(io.BytesIO(uploaded[filename]))
    input_tensor = preprocess_image(img_pil)

    # Predict
    prediction = model.predict(input_tensor)[0]
    if prediction.shape[-1] > 1:
        prediction_mask = np.argmax(prediction, axis=-1)
    else:
        prediction_mask = prediction.squeeze()

    # Threshold if binary
    prediction_mask = (prediction_mask > 0.5).astype(np.uint8)

    # Overlay
    overlay = overlay_mask(img_pil, prediction_mask)

    # Plot
    plt.figure(figsize=(12,4))
    plt.subplot(1,3,1)
    plt.imshow(img_pil)
    plt.title("Original")
    plt.axis('off')

    plt.subplot(1,3,2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title("Predicted Mask")
    plt.axis('off')

    plt.subplot(1,3,3)
    plt.imshow(overlay)
    plt.title("Overlay")
    plt.axis('off')

    plt.tight_layout()
    plt.show()
